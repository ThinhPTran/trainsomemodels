# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
image = np.fromfile("../Image/dofoutput_mode_no_fusion/outputimage_dof_l1.bin", dtype=np.uint16)
cv2.imwrite("../Image/Output_Lib_L1_408_1920.png", image.reshape((408,1920)))
# Out:
# True

# %%
image_L1_408_1920 = cv2.imread("../Image/Output_Lib_L1_408_1920.png")
image_L1_408_1920_gray = cv2.cvtColor(image_L1_408_1920, cv2.COLOR_BGR2GRAY)

# %%
Vx = np.zeros((408,960))
Vy = np.zeros((408,960))

# %%
for i in range(408):
    for j in range(960):
        Vx[i, j] = image_L1_408_1920_gray[i, 2*j+0]
        Vy[i, j] = image_L1_408_1920_gray[i, 2*j+1]

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(image_L1_408_1920_gray)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(Vx)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(Vy)
