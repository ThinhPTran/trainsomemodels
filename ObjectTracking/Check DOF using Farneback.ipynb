# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
image = np.fromfile("../Image/L1_image.bin", dtype=np.uint16)
cv2.imwrite("../Image/L1_image_prv.png", image.reshape((820,1920)))
# Out:
# True

# %%
image = np.fromfile("../Image/L2_image.bin", dtype=np.uint16)
cv2.imwrite("../Image/L2_image_prv.png", image.reshape((410,960)))
# Out:
# True

# %%
image = np.fromfile("../Image/L3_image.bin", dtype=np.uint16)
cv2.imwrite("../Image/L3_image_prv.png", image.reshape((205,480)))
# Out:
# True

# %%
image = np.fromfile("../Image/L11_image.bin", dtype=np.uint16)
cv2.imwrite("../Image/L1_image_cur.png", image.reshape((820,1920)))
# Out:
# True

# %%
image = np.fromfile("../Image/L21_image.bin", dtype=np.uint16)
cv2.imwrite("../Image/L2_image_cur.png", image.reshape((410,960)))
# Out:
# True

# %%
image = np.fromfile("../Image/L31_image.bin", dtype=np.uint16)
cv2.imwrite("../Image/L3_image_cur.png", image.reshape((205,480)))
# Out:
# True

# %%
image_L3_cur = cv2.imread("../Image/L3_image_cur.png")
image_L3_prv = cv2.imread("../Image/L3_image_prv.png")

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(image_L3_cur)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(image_L3_prv)

# %%
diff_L3 = image_L3_cur - image_L3_prv
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(diff_L3)

# %% [markdown]
# f, axarr = plt.subplots(1,1, figsize=(20, 20))
# axarr.imshow(diff_L3)

# %% [markdown]
# ![Farneback.png](attachment:Farneback.png)

# %%
gray_cur = cv2.cvtColor(image_L3_cur, cv2.COLOR_BGR2GRAY)
gray_prv = cv2.cvtColor(image_L3_prv, cv2.COLOR_BGR2GRAY)
flow = cv2.calcOpticalFlowFarneback(gray_prv, gray_cur, None, 0.5, 3, 5, 3, 5, 1.2, 0)

# %%
flowx = flow[...,0]
flowy = flow[...,1]

# %%
flowxscale = cv2.normalize(flowx, None, 0, 255, cv2.NORM_MINMAX)
flowyscale = cv2.normalize(flowy, None, 0, 255, cv2.NORM_MINMAX)

# %%
flowxscale.shape
# Out:
# (205, 480)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(flowxscale)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(flowyscale)

# %%
image_L1_cur = cv2.imread("../Image/L1_image_cur.png")
image_L1_prv = cv2.imread("../Image/L1_image_prv.png")
gray_cur = cv2.cvtColor(image_L1_cur, cv2.COLOR_BGR2GRAY)
gray_prv = cv2.cvtColor(image_L1_prv, cv2.COLOR_BGR2GRAY)
flow = cv2.calcOpticalFlowFarneback(gray_prv, gray_cur, None, 0.5, 3, 15, 3, 5, 1.2, 0)
flowx = flow[...,0]
flowy = flow[...,1]
flowxscale = cv2.normalize(flowx, None, 0, 255, cv2.NORM_MINMAX)
flowyscale = cv2.normalize(flowy, None, 0, 255, cv2.NORM_MINMAX)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(flowxscale)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(flowyscale)

# %%
image_L2_cur = cv2.imread("../Image/L2_image_cur.png")
image_L2_prv = cv2.imread("../Image/L2_image_prv.png")
gray_cur = cv2.cvtColor(image_L2_cur, cv2.COLOR_BGR2GRAY)
gray_prv = cv2.cvtColor(image_L2_prv, cv2.COLOR_BGR2GRAY)
flow = cv2.calcOpticalFlowFarneback(gray_prv, gray_cur, None, 0.5, 3, 5, 15, 5, 1.2, 0)
flowx = flow[...,0]
flowy = flow[...,1]
flowxscale = cv2.normalize(flowx, None, 0, 255, cv2.NORM_MINMAX)
flowyscale = cv2.normalize(flowy, None, 0, 255, cv2.NORM_MINMAX)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(flowxscale)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(flowyscale)

# %%
image_L3_cur = cv2.imread("../Image/L3_image_cur.png")
image_L3_prv = cv2.imread("../Image/L3_image_prv.png")
gray_cur = cv2.cvtColor(image_L3_cur, cv2.COLOR_BGR2GRAY)
gray_prv = cv2.cvtColor(image_L3_prv, cv2.COLOR_BGR2GRAY)
flow = cv2.calcOpticalFlowFarneback(gray_prv, gray_cur, None, 0.5, 3, 15, 3, 5, 1.2, 0)
flowx = flow[...,0]
flowy = flow[...,1]
flowxscale = cv2.normalize(flowx, None, 0, 255, cv2.NORM_MINMAX)
flowyscale = cv2.normalize(flowy, None, 0, 255, cv2.NORM_MINMAX)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(flowxscale)

# %%
f, axarr = plt.subplots(1,1, figsize=(20, 20))
axarr.imshow(flowyscale)
