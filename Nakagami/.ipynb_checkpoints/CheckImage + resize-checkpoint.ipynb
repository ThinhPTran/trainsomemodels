# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %%
img_car1 = Image.open("../Image/car_no_light.jpg")
img_car2 = Image.open("../Image/car_with_brake_light.jpg")

# %%
plt.imshow(img_car1)

# %%
plt.imshow(img_car2)

# %%
img_car1.mode
# Out:
# 'RGB'

# %%
img_car2.mode
# Out:
# 'RGB'

# %%
img_car1.size
# Out:
# (1334, 750)

# %%
img_car2.size
# Out:
# (1280, 557)

# %%
img_car1_out = img_car1.resize((1280,720))
img_car2_out = img_car2.resize((1280,720))

# %%
img_car1_out.size
# Out:
# (1280, 720)

# %%
plt.imshow(img_car1_out)

# %%
plt.imshow(img_car2_out)

# %%
img_car1_out.save('../Data/car_no_light_1280x720.jpg')
img_car2_out.save('../Data/car_with_brake_light_1280x720.jpg')

# %%
img_car1_in = Image.open('../Data/car_no_light_1280x720.jpg')
img_car2_in = Image.open('../Data/car_with_brake_light_1280x720.jpg')

# %%
plt.imshow(img_car1_in)

# %%
plt.imshow(img_car2_in)
